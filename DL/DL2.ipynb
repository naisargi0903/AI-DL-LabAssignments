# %%
from google.colab.patches import cv2_imshow
import cv2

# Load the photograph
pixels = cv2.imread('/content/girlfaceimage2.jpeg')

# Load the pre-trained model (make sure the haarcascade file is in the correct path)
classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Perform face detection
bboxes = classifier.detectMultiScale(pixels)

# Print bounding box for each detected face
for box in bboxes:
    # Extract coordinates
    x, y, width, height = box
    x2, y2 = x + width, y + height
    # Draw a rectangle over the pixels
    cv2.rectangle(pixels, (x, y), (x2, y2), (0, 0, 255), 2)

# Show the image
cv2_imshow(pixels)
# Out:
# <PIL.Image.Image image mode=RGB size=266x190>
